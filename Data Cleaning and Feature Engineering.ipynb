# %% [markdown]
# # Supply Chain Data Set: Exploratory Analysis and Insights

# %% [markdown]
# ## Part 1: Data Cleaning and Feature Engineering

# %% [markdown]
# Dataset Link: https://www.kaggle.com/datasets/shashwatwork/dataco-smart-supply-chain-for-big-data-analysis

# %% [markdown]
# ##  Reading Data:

# %%
# Importing all header files necessary for the run
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reads the file having the dataset
ds = pd.read_csv('DataCoSupplyChainDataset.csv',header= 0,encoding='unicode_escape')

# %%
# prints the first five lines of the read dataset
ds.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# 1                   1           73  Sporting Goods        Caguas  ...
# 2                   0           73  Sporting Goods      San Jose  ...
# 3                   0           73  Sporting Goods   Los Angeles  ...
# 4                   0           73  Sporting Goods        Caguas  ...
#
#   Order Zipcode Product Card Id Product Category Id  Product Description  \
# 0           NaN            1360                  73                  NaN
# 1           NaN            1360                  73                  NaN
# 2           NaN            1360                  73                  NaN
# 3           NaN            1360                  73                  NaN
# 4           NaN            1360                  73                  NaN
#
#                                   Product Image  Product Name Product Price  \
# 0  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 1  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 2  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 3  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 4  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
#
#   Product Status shipping date (DateOrders)   Shipping Mode
# 0              0             2/3/2018 22:56  Standard Class
# 1              0            1/18/2018 12:27  Standard Class
# 2              0            1/17/2018 12:06  Standard Class
# 3              0            1/16/2018 11:45  Standard Class
# 4              0            1/15/2018 11:24  Standard Class
#
# [5 rows x 53 columns]

# %%
# Display the column names from the dataset
ds.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
#        'Order Zipcode', 'Product Card Id', 'Product Category Id',
#        'Product Description', 'Product Image', 'Product Name', 'Product Price',
#        'Product Status', 'shipping date (DateOrders)', 'Shipping Mode'],
#       dtype='object')

# %%
# Checks for duplicates in the dataset
ds.duplicated().sum()
# Out:
# 0

# %%
# Displays the shape of the dataset
ds.shape
# Out:
# (180519, 53)

# %%
# Shows the information about the dataset
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
#  12  Customer Fname                 180519 non-null  object
#  13  Customer Id                    180519 non-null  int64
#  14  Customer Lname                 180511 non-null  object
#  15  Customer Password              180519 non-null  object
#  16  Customer Segment               180519 non-null  object
#  17  Customer State                 180519 non-null  object
#  18  Customer Street                180519 non-null  object
#  19  Customer Zipcode               180516 non-null  float64
#  20  Department Id                  180519 non-null  int64
#  21  Department Name                180519 non-null  object
#  22  Latitude                       180519 non-null  float64
#  23  Longitude                      180519 non-null  float64
#  24  Market                         180519 non-null  object
#  25  Order City                     180519 non-null  object
#  26  Order Country                  180519 non-null  object
#  27  Order Customer Id              180519 non-null  int64
#  28  order date (DateOrders)        180519 non-null  object
#  29  Order Id                       180519 non-null  int64
#  30  Order Item Cardprod Id         180519 non-null  int64
#  31  Order Item Discount            180519 non-null  float64
#  32  Order Item Discount Rate       180519 non-null  float64
#  33  Order Item Id                  180519 non-null  int64
#  34  Order Item Product Price       180519 non-null  float64
#  35  Order Item Profit Ratio        180519 non-null  float64
#  36  Order Item Quantity            180519 non-null  int64
#  37  Sales                          180519 non-null  float64
#  38  Order Item Total               180519 non-null  float64
#  39  Order Profit Per Order         180519 non-null  float64
#  40  Order Region                   180519 non-null  object
#  41  Order State                    180519 non-null  object
#  42  Order Status                   180519 non-null  object
#  43  Order Zipcode                  24840 non-null   float64
#  44  Product Card Id                180519 non-null  int64
#  45  Product Category Id            180519 non-null  int64
#  46  Product Description            0 non-null       float64
#  47  Product Image                  180519 non-null  object
#  48  Product Name                   180519 non-null  object
#  49  Product Price                  180519 non-null  float64
#  50  Product Status                 180519 non-null  int64
#  51  shipping date (DateOrders)     180519 non-null  object
#  52  Shipping Mode                  180519 non-null  object
# dtypes: float64(15), int64(14), object(24)
# memory usage: 73.0+ MB

# %%
# Shows the correaltion between the column names of the dataset
ds.corr()
# Out:
#                                Days for shipping (real)  \
# Days for shipping (real)                       1.000000
# Days for shipment (scheduled)                  0.515880
# Benefit per order                             -0.005101
# Sales per customer                             0.001757
# Late_delivery_risk                             0.401415
# Category Id                                   -0.000348
# Customer Id                                    0.003432
# Customer Zipcode                               0.000112
# Department Id                                 -0.001631
# Latitude                                      -0.004073
# Longitude                                      0.003911
# Order Customer Id                              0.003432
# Order Id                                      -0.001711
# Order Item Cardprod Id                        -0.000859
# Order Item Discount                            0.002231
# Order Item Discount Rate                       0.001467
# Order Item Id                                 -0.001769
# Order Item Product Price                       0.002185
# Order Item Profit Ratio                       -0.004638
# Order Item Quantity                           -0.000811
# Sales                                          0.001962
# Order Item Total                               0.001757
# Order Profit Per Order                        -0.005101
# Order Zipcode                                 -0.000811
# Product Card Id                               -0.000859
# Product Category Id                           -0.000348
# Product Description                                 NaN
# Product Price                                  0.002185
# Product Status                                      NaN
#
#                                Days for shipment (scheduled)  \
# Days for shipping (real)                            0.515880
# Days for shipment (scheduled)                       1.000000
# Benefit per order                                  -0.000185
# Sales per customer                                  0.006445
# Late_delivery_risk                                 -0.369352
# Category Id                                        -0.000367
# Customer Id                                         0.000899
# Customer Zipcode                                   -0.003019
# Department Id                                      -0.000262
# Latitude                                           -0.005300
# Longitude                                           0.003675
# Order Customer Id                                   0.000899
# Order Id                                           -0.001878
# Order Item Cardprod Id                             -0.000431
# Order Item Discount                                 0.002897
# Order Item Discount Rate                            0.000065
# Order Item Id                                      -0.001848
# Order Item Product Price                            0.006912
# Order Item Profit Ratio                            -0.001822
# Order Item Quantity                                -0.002925
# Sales                                               0.006327
# Order Item Total                                    0.006445
# Order Profit Per Order                             -0.000185
# Order Zipcode                                       0.005249
# Product Card Id                                    -0.000431
# Product Category Id                                -0.000367
# Product Description                                      NaN
# Product Price                                       0.006912
# Product Status                                           NaN
#
#                                Benefit per order  Sales per customer  \
# Days for shipping (real)               -0.005101            0.001757
# Days for shipment (scheduled)          -0.000185            0.006445
# Benefit per order                       1.000000            0.133484
# Sales per customer                      0.133484            1.000000
# Late_delivery_risk                     -0.003727           -0.003791
# Category Id                             0.031889            0.225201
# Customer Id                             0.009354            0.060181
# Customer Zipcode                        0.002235           -0.001304
# Department Id                           0.031442            0.232367
# Latitude                                0.000338           -0.000223
# Longitude                              -0.002521            0.001444
# Order Customer Id                       0.009354            0.060181
# Order Id                                0.013716            0.079000
# Order Item Cardprod Id                  0.033161            0.236367
# Order Item Discount                     0.064756            0.498734
# Order Item Discount Rate               -0.018644           -0.119469
# Order Item Id                           0.013556            0.078176
# Order Item Product Price                0.103459            0.781781
# Order Item Profit Ratio                 0.823689           -0.001439
# Order Item Quantity                     0.015696            0.105413
# Sales                                   0.131816            0.989744
# Order Item Total                        0.133484            1.000000
# Order Profit Per Order                  1.000000            0.133484
# Order Zipcode                          -0.004978           -0.000138
# Product Card Id                         0.033161            0.236367
# Product Category Id                     0.031889            0.225201
# Product Description                          NaN                 NaN
# Product Price                           0.103459            0.781781
# Product Status                               NaN                 NaN
#
#                                Late_delivery_risk  Category Id  Customer Id  \
# Days for shipping (real)                 0.401415    -0.000348     0.003432
# Days for shipment (scheduled)           -0.369352    -0.000367     0.000899
# Benefit per order                       -0.003727     0.031889     0.009354
# Sales per customer                      -0.003791     0.225201     0.060181
# Late_delivery_risk                       1.000000     0.001752     0.001484
# Category Id                              0.001752     1.000000     0.274633
# Customer Id                              0.001484     0.274633     1.000000
# Customer Zipcode                         0.003148     0.002898     0.002022
# Department Id                            0.001077     0.888835     0.136897
# Latitude                                 0.000679     0.002195     0.002335
# Longitude                               -0.001915    -0.002320    -0.005146
# Order Customer Id                        0.001484     0.274633     1.000000
# Order Id                                -0.001293     0.198496     0.204821
# Order Item Cardprod Id                   0.001490     0.991092     0.228039
# Order Item Discount                     -0.000750     0.140180     0.038490
# Order Item Discount Rate                 0.000404     0.000572     0.001712
# Order Item Id                           -0.001376     0.186796     0.191814
# Order Item Product Price                -0.002175     0.461059     0.111118
# Order Item Profit Ratio                 -0.002316    -0.001614    -0.000337
# Order Item Quantity                     -0.000139    -0.302408    -0.091328
# Sales                                   -0.003564     0.227483     0.060961
# Order Item Total                        -0.003791     0.225201     0.060181
# Order Profit Per Order                  -0.003727     0.031889     0.009354
# Order Zipcode                           -0.014131    -0.005943    -0.005659
# Product Card Id                          0.001490     0.991092     0.228039
# Product Category Id                      0.001752     1.000000     0.274633
# Product Description                           NaN          NaN          NaN
# Product Price                           -0.002175     0.461059     0.111118
# Product Status                                NaN          NaN          NaN
#
#                                Customer Zipcode  Department Id  Latitude  ...  \
# Days for shipping (real)               0.000112      -0.001631 -0.004073  ...
# Days for shipment (scheduled)         -0.003019      -0.000262 -0.005300  ...
# Benefit per order                      0.002235       0.031442  0.000338  ...
# Sales per customer                    -0.001304       0.232367 -0.000223  ...
# Late_delivery_risk                     0.003148       0.001077  0.000679  ...
# Category Id                            0.002898       0.888835  0.002195  ...
# Customer Id                            0.002022       0.136897  0.002335  ...
# Customer Zipcode                       1.000000       0.002878  0.584553  ...
# Department Id                          0.002878       1.000000  0.002460  ...
# Latitude                               0.584553       0.002460  1.000000  ...
# Longitude                             -0.923921      -0.002435 -0.525122  ...
# Order Customer Id                      0.002022       0.136897  0.002335  ...
# Order Id                              -0.001210       0.106757 -0.002984  ...
# Order Item Cardprod Id                 0.003173       0.906117  0.002031  ...
# Order Item Discount                   -0.001861       0.144617 -0.002997  ...
# Order Item Discount Rate              -0.000135       0.000255 -0.003889  ...
# Order Item Id                         -0.001208       0.101676 -0.003058  ...
# Order Item Product Price               0.002191       0.446743  0.000471  ...
# Order Item Profit Ratio                0.003364      -0.003044 -0.000081  ...
# Order Item Quantity                   -0.006174      -0.265437 -0.001853  ...
# Sales                                 -0.001490       0.234718 -0.000696  ...
# Order Item Total                      -0.001304       0.232367 -0.000223  ...
# Order Profit Per Order                 0.002235       0.031442  0.000338  ...
# Order Zipcode                          0.011843      -0.005982 -0.002921  ...
# Product Card Id                        0.003173       0.906117  0.002031  ...
# Product Category Id                    0.002898       0.888835  0.002195  ...
# Product Description                         NaN            NaN       NaN  ...
# Product Price                          0.002191       0.446743  0.000471  ...
# Product Status                              NaN            NaN       NaN  ...
#
#                                Order Item Quantity     Sales  \
# Days for shipping (real)                 -0.000811  0.001962
# Days for shipment (scheduled)            -0.002925  0.006327
# Benefit per order                         0.015696  0.131816
# Sales per customer                        0.105413  0.989744
# Late_delivery_risk                       -0.000139 -0.003564
# Category Id                              -0.302408  0.227483
# Customer Id                              -0.091328  0.060961
# Customer Zipcode                         -0.006174 -0.001490
# Department Id                            -0.265437  0.234718
# Latitude                                 -0.001853 -0.000696
# Longitude                                 0.004467  0.001696
# Order Customer Id                        -0.091328  0.060961
# Order Id                                 -0.087073  0.079835
# Order Item Cardprod Id                   -0.312555  0.238789
# Order Item Discount                       0.065379  0.617438
# Order Item Discount Rate                 -0.000028  0.000346
# Order Item Id                            -0.083643  0.079002
# Order Item Product Price                 -0.476232  0.789948
# Order Item Profit Ratio                   0.001128 -0.001766
# Order Item Quantity                       1.000000  0.106442
# Sales                                     0.106442  1.000000
# Order Item Total                          0.105413  0.989744
# Order Profit Per Order                    0.015696  0.131816
# Order Zipcode                             0.001662  0.000564
# Product Card Id                          -0.312555  0.238789
# Product Category Id                      -0.302408  0.227483
# Product Description                            NaN       NaN
# Product Price                            -0.476232  0.789948
# Product Status                                 NaN       NaN
#
#                                Order Item Total  Order Profit Per Order  \
# Days for shipping (real)               0.001757               -0.005101
# Days for shipment (scheduled)          0.006445               -0.000185
# Benefit per order                      0.133484                1.000000
# Sales per customer                     1.000000                0.133484
# Late_delivery_risk                    -0.003791               -0.003727
# Category Id                            0.225201                0.031889
# Customer Id                            0.060181                0.009354
# Customer Zipcode                      -0.001304                0.002235
# Department Id                          0.232367                0.031442
# Latitude                              -0.000223                0.000338
# Longitude                              0.001444               -0.002521
# Order Customer Id                      0.060181                0.009354
# Order Id                               0.079000                0.013716
# Order Item Cardprod Id                 0.236367                0.033161
# Order Item Discount                    0.498734                0.064756
# Order Item Discount Rate              -0.119469               -0.018644
# Order Item Id                          0.078176                0.013556
# Order Item Product Price               0.781781                0.103459
# Order Item Profit Ratio               -0.001439                0.823689
# Order Item Quantity                    0.105413                0.015696
# Sales                                  0.989744                0.131816
# Order Item Total                       1.000000                0.133484
# Order Profit Per Order                 0.133484                1.000000
# Order Zipcode                         -0.000138               -0.004978
# Product Card Id                        0.236367                0.033161
# Product Category Id                    0.225201                0.031889
# Product Description                         NaN                     NaN
# Product Price                          0.781781                0.103459
# Product Status                              NaN                     NaN
#
#                                Order Zipcode  Product Card Id  \
# Days for shipping (real)           -0.000811        -0.000859
# Days for shipment (scheduled)       0.005249        -0.000431
# Benefit per order                  -0.004978         0.033161
# Sales per customer                 -0.000138         0.236367
# Late_delivery_risk                 -0.014131         0.001490
# Category Id                        -0.005943         0.991092
# Customer Id                        -0.005659         0.228039
# Customer Zipcode                    0.011843         0.003173
# Department Id                      -0.005982         0.906117
# Latitude                           -0.002921         0.002031
# Longitude                          -0.005880        -0.002580
# Order Customer Id                  -0.005659         0.228039
# Order Id                            0.013971         0.163416
# Order Item Cardprod Id             -0.005658         1.000000
# Order Item Discount                 0.003921         0.147294
# Order Item Discount Rate            0.002691         0.000731
# Order Item Id                       0.013867         0.154077
# Order Item Product Price           -0.000121         0.480288
# Order Item Profit Ratio            -0.005650        -0.001784
# Order Item Quantity                 0.001662        -0.312555
# Sales                               0.000564         0.238789
# Order Item Total                   -0.000138         0.236367
# Order Profit Per Order             -0.004978         0.033161
# Order Zipcode                       1.000000        -0.005658
# Product Card Id                    -0.005658         1.000000
# Product Category Id                -0.005943         0.991092
# Product Description                      NaN              NaN
# Product Price                      -0.000121         0.480288
# Product Status                           NaN              NaN
#
#                                Product Category Id  Product Description  \
# Days for shipping (real)                 -0.000348                  NaN
# Days for shipment (scheduled)            -0.000367                  NaN
# Benefit per order                         0.031889                  NaN
# Sales per customer                        0.225201                  NaN
# Late_delivery_risk                        0.001752                  NaN
# Category Id                               1.000000                  NaN
# Customer Id                               0.274633                  NaN
# Customer Zipcode                          0.002898                  NaN
# Department Id                             0.888835                  NaN
# Latitude                                  0.002195                  NaN
# Longitude                                -0.002320                  NaN
# Order Customer Id                         0.274633                  NaN
# Order Id                                  0.198496                  NaN
# Order Item Cardprod Id                    0.991092                  NaN
# Order Item Discount                       0.140180                  NaN
# Order Item Discount Rate                  0.000572                  NaN
# Order Item Id                             0.186796                  NaN
# Order Item Product Price                  0.461059                  NaN
# Order Item Profit Ratio                  -0.001614                  NaN
# Order Item Quantity                      -0.302408                  NaN
# Sales                                     0.227483                  NaN
# Order Item Total                          0.225201                  NaN
# Order Profit Per Order                    0.031889                  NaN
# Order Zipcode                            -0.005943                  NaN
# Product Card Id                           0.991092                  NaN
# Product Category Id                       1.000000                  NaN
# Product Description                            NaN                  NaN
# Product Price                             0.461059                  NaN
# Product Status                                 NaN                  NaN
#
#                                Product Price  Product Status
# Days for shipping (real)            0.002185             NaN
# Days for shipment (scheduled)       0.006912             NaN
# Benefit per order                   0.103459             NaN
# Sales per customer                  0.781781             NaN
# Late_delivery_risk                 -0.002175             NaN
# Category Id                         0.461059             NaN
# Customer Id                         0.111118             NaN
# Customer Zipcode                    0.002191             NaN
# Department Id                       0.446743             NaN
# Latitude                            0.000471             NaN
# Longitude                          -0.000894             NaN
# Order Customer Id                   0.111118             NaN
# Order Id                            0.115324             NaN
# Order Item Cardprod Id              0.480288             NaN
# Order Item Discount                 0.488101             NaN
# Order Item Discount Rate            0.000345             NaN
# Order Item Id                       0.112448             NaN
# Order Item Product Price            1.000000             NaN
# Order Item Profit Ratio            -0.002043             NaN
# Order Item Quantity                -0.476232             NaN
# Sales                               0.789948             NaN
# Order Item Total                    0.781781             NaN
# Order Profit Per Order              0.103459             NaN
# Order Zipcode                      -0.000121             NaN
# Product Card Id                     0.480288             NaN
# Product Category Id                 0.461059             NaN
# Product Description                      NaN             NaN
# Product Price                       1.000000             NaN
# Product Status                           NaN             NaN
#
# [29 rows x 29 columns]

# %% [markdown]
# ## Sorting Data Based on Requirement

# %%
# Dropping columns which doesnt seem to be necessary for the analysis
col_dropped=['Days for shipping (real)', 'Days for shipment (scheduled)',
       'Sales per customer','Category Id','Customer Fname','Customer Lname','Customer City','Customer Email',
       'Customer Password','Customer State', 'Customer Street', 'Customer Zipcode',
       'Department Id','Latitude', 'Longitude','Order Item Discount',
       'Order City','Order Customer Id','Order Id', 'Order Item Cardprod Id',
       'Order Item Id','Order Item Profit Ratio','Order Profit Per Order',
       'Order Item Quantity','Order Item Total','Order State',
       'Order Zipcode', 'Product Card Id', 'Product Category Id',
       'Product Description', 'Product Image','Product Price',
       'Product Status']
ds.drop(col_dropped,axis=1,inplace=True)

# Confirming the remaining names of columns after dropping the unnecessary
ds.columns
# Out:
# Index(['Type', 'Benefit per order', 'Delivery Status', 'Late_delivery_risk',
#        'Category Name', 'Customer Country', 'Customer Id', 'Customer Segment',
#        'Department Name', 'Market', 'Order Country', 'order date (DateOrders)',
#        'Order Item Discount Rate', 'Order Item Product Price', 'Sales',
#        'Order Region', 'Order Status', 'Product Name',
#        'shipping date (DateOrders)', 'Shipping Mode'],
#       dtype='object')

# %%
# Formatting the date's columns
date_cols = ['order date (DateOrders)', 'shipping date (DateOrders)']
for col in date_cols:
    ds[col] = pd.to_datetime(ds[col])

# %% [markdown]
# ## Reading and Understanding the Data:

# %% [markdown]
# ### Initial Exploration on Data:

# %%
#Checking for null values
ds.isnull().sum()
# Out:
# Type                          0
# Benefit per order             0
# Delivery Status               0
# Late_delivery_risk            0
# Category Name                 0
# Customer Country              0
# Customer Id                   0
# Customer Segment              0
# Department Name               0
# Market                        0
# Order Country                 0
# order date (DateOrders)       0
# Order Item Discount Rate      0
# Order Item Product Price      0
# Sales                         0
# Order Region                  0
# Order Status                  0
# Product Name                  0
# shipping date (DateOrders)    0
# Shipping Mode                 0
# dtype: int64

# %%
# Observing the statistical characteristics of the dataset 
ds.describe()
# Out:
#        Benefit per order  Late_delivery_risk    Customer Id  \
# count      180519.000000       180519.000000  180519.000000
# mean           21.974989            0.548291    6691.379495
# std           104.433526            0.497664    4162.918106
# min         -4274.979980            0.000000       1.000000
# 25%             7.000000            0.000000    3258.500000
# 50%            31.520000            1.000000    6457.000000
# 75%            64.800003            1.000000    9779.000000
# max           911.799988            1.000000   20757.000000
#
#        Order Item Discount Rate  Order Item Product Price          Sales
# count             180519.000000             180519.000000  180519.000000
# mean                   0.101668                141.232550     203.772096
# std                    0.070415                139.732492     132.273077
# min                    0.000000                  9.990000       9.990000
# 25%                    0.040000                 50.000000     119.980003
# 50%                    0.100000                 59.990002     199.919998
# 75%                    0.160000                199.990005     299.950012
# max                    0.250000               1999.989990    1999.989990

# %%
#Checking for duplicate
ds.duplicated().sum()
# Out:
# 0

# %%
# Check for the number of rows and columns in the dataset
ds.shape
# Out:
# (180519, 20)

# %% [markdown]
# ### Checking Value Counts of Each Column to understand the columns in depth

# %%
# Payment Type
ds['Type'].value_counts()
# Out:
# DEBIT       69295
# TRANSFER    49883
# PAYMENT     41725
# CASH        19616
# Name: Type, dtype: int64

# %%
# Benefit per Order
ds['Benefit per order'].value_counts()
# Out:
#  0.000000      1177
#  143.990005     199
#  72.000000      194
#  46.799999      188
#  24.000000      181
#                ...
# -48.830002        1
#  48.220001        1
# -145.729996       1
# -330.109985       1
# -337.100006       1
# Name: Benefit per order, Length: 21998, dtype: int64

# %%
# Creating a bracket to determine profit and loss
d = ds['Benefit per order']
BenefitBracket = np.where(d < 0, 'Loss',
                np.where(d == 0, 'No Profit No Loss',
                         np.where(d > 0, 'Profit', np.nan)))

ds["BenefitBracket"] = pd.Categorical(BenefitBracket,
                            categories=['Loss', 'No Profit No Loss', 'Profit'],
                            ordered=True)

ds.head()
# Out:
#        Type  Benefit per order   Delivery Status  Late_delivery_risk  \
# 0     DEBIT          91.250000  Advance shipping                   0
# 1  TRANSFER        -249.089996     Late delivery                   1
# 2      CASH        -247.779999  Shipping on time                   0
# 3     DEBIT          22.860001  Advance shipping                   0
# 4   PAYMENT         134.210007  Advance shipping                   0
#
#     Category Name Customer Country  Customer Id Customer Segment  \
# 0  Sporting Goods      Puerto Rico        20755         Consumer
# 1  Sporting Goods      Puerto Rico        19492         Consumer
# 2  Sporting Goods          EE. UU.        19491         Consumer
# 3  Sporting Goods          EE. UU.        19490      Home Office
# 4  Sporting Goods      Puerto Rico        19489        Corporate
#
#   Department Name        Market  ... order date (DateOrders)  \
# 0         Fitness  Pacific Asia  ...     2018-01-31 22:56:00
# 1         Fitness  Pacific Asia  ...     2018-01-13 12:27:00
# 2         Fitness  Pacific Asia  ...     2018-01-13 12:06:00
# 3         Fitness  Pacific Asia  ...     2018-01-13 11:45:00
# 4         Fitness  Pacific Asia  ...     2018-01-13 11:24:00
#
#   Order Item Discount Rate  Order Item Product Price   Sales    Order Region  \
# 0                     0.04                    327.75  327.75  Southeast Asia
# 1                     0.05                    327.75  327.75      South Asia
# 2                     0.06                    327.75  327.75      South Asia
# 3                     0.07                    327.75  327.75         Oceania
# 4                     0.09                    327.75  327.75         Oceania
#
#       Order Status  Product Name shipping date (DateOrders)   Shipping Mode  \
# 0         COMPLETE  Smart watch         2018-02-03 22:56:00  Standard Class
# 1          PENDING  Smart watch         2018-01-18 12:27:00  Standard Class
# 2           CLOSED  Smart watch         2018-01-17 12:06:00  Standard Class
# 3         COMPLETE  Smart watch         2018-01-16 11:45:00  Standard Class
# 4  PENDING_PAYMENT  Smart watch         2018-01-15 11:24:00  Standard Class
#
#   BenefitBracket
# 0         Profit
# 1           Loss
# 2           Loss
# 3         Profit
# 4         Profit
#
# [5 rows x 21 columns]

# %%
# Delivery Status
ds['Delivery Status'].value_counts()
# Out:
# Late delivery        98977
# Advance shipping     41592
# Shipping on time     32196
# Shipping canceled     7754
# Name: Delivery Status, dtype: int64

# %%
# Risk of Late Delivery
ds['Late_delivery_risk'].value_counts()
# Out:
# 1    98977
# 0    81542
# Name: Late_delivery_risk, dtype: int64

# %%
# Category Name
ds['Category Name'].value_counts()
# Out:
# Cleats                  24551
# Men's Footwear          22246
# Women's Apparel         21035
# Indoor/Outdoor Games    19298
# Fishing                 17325
# Water Sports            15540
# Camping & Hiking        13729
# Cardio Equipment        12487
# Shop By Sport           10984
# Electronics              3156
# Accessories              1780
# Golf Balls               1475
# Girls' Apparel           1201
# Golf Gloves              1070
# Trade-In                  974
# Video Games               838
# Children's Clothing       652
# Women's Clothing          650
# Baseball & Softball       632
# Hockey                    614
# Cameras                   592
# Toys                      529
# Golf Shoes                524
# Pet Supplies              492
# Garden                    484
# Crafts                    484
# DVDs                      483
# Computers                 442
# Golf Apparel              441
# Hunting & Shooting        440
# Music                     434
# Consumer Electronics      431
# Boxing & MMA              423
# Books                     405
# Kids' Golf Clubs          384
# Health and Beauty         362
# Sporting Goods            357
# Lacrosse                  343
# Tennis & Racquet          328
# Fitness Accessories       309
# Men's Golf Clubs          283
# CDs                       271
# Men's Clothing            208
# Baby                      207
# Women's Golf Clubs        181
# Soccer                    138
# Strength Training         111
# As Seen on  TV!            68
# Basketball                 67
# Golf Bags & Carts          61
# Name: Category Name, dtype: int64

# %%
# Customer's Country
ds['Customer Country'].value_counts()
# Out:
# EE. UU.        111146
# Puerto Rico     69373
# Name: Customer Country, dtype: int64

# %%
# Customer's Segment
ds['Customer Segment'].value_counts()
# Out:
# Consumer       93504
# Corporate      54789
# Home Office    32226
# Name: Customer Segment, dtype: int64

# %%
# Product Department Name
ds['Department Name'].value_counts()
# Out:
# Fan Shop              66861
# Apparel               48998
# Golf                  33220
# Footwear              14525
# Outdoors               9686
# Fitness                2479
# Discs Shop             2026
# Technology             1465
# Pet Shop                492
# Book Shop               405
# Health and Beauty       362
# Name: Department Name, dtype: int64

# %%
# Sales Market
ds['Market'].value_counts()
# Out:
# LATAM           51594
# Europe          50252
# Pacific Asia    41260
# USCA            25799
# Africa          11614
# Name: Market, dtype: int64

# %%
# Order Country
ds['Order Country'].value_counts()
# Out:
# Estados Unidos       24840
# Francia              13222
# México               13172
# Alemania              9564
# Australia             8497
#                      ...
# Guinea Ecuatorial        2
# Kuwait                   2
# Sáhara Occidental        2
# Burundi                  1
# Serbia                   1
# Name: Order Country, Length: 164, dtype: int64

# %%
# Date of Order
ds['order date (DateOrders)'].value_counts()
# Out:
# 2016-12-14 12:29:00    5
# 2015-02-22 14:38:00    5
# 2016-02-17 14:08:00    5
# 2016-12-31 09:50:00    5
# 2016-02-11 16:35:00    5
#                       ..
# 2016-09-05 05:58:00    1
# 2016-09-06 01:56:00    1
# 2016-09-06 03:20:00    1
# 2016-09-06 19:27:00    1
# 2016-01-17 05:56:00    1
# Name: order date (DateOrders), Length: 65752, dtype: int64

# %%
# Discount rate of the ordered Item
ds['Order Item Discount Rate'].value_counts()
# Out:
# 0.04    10029
# 0.15    10029
# 0.25    10029
# 0.20    10029
# 0.18    10029
# 0.17    10029
# 0.05    10029
# 0.16    10029
# 0.13    10029
# 0.12    10029
# 0.10    10029
# 0.09    10029
# 0.07    10029
# 0.06    10029
# 0.03    10029
# 0.00    10028
# 0.01    10028
# 0.02    10028
# Name: Order Item Discount Rate, dtype: int64

# %%
# # Range for the Order Discount Rates 
d = ds['Order Item Discount Rate']
OrdDiscBracket = np.where(d <= 0.10, '<10%',
                np.where(d <= 0.20, '<20%',
                         np.where(d > 0.20, '>20%', np.nan)))

ds["Order Item Discount Bracket"] = pd.Categorical(OrdDiscBracket,
                            categories=['<10%', '<20%', '>20%'],
                            ordered=True)

ds.head()
# Out:
#        Type  Benefit per order   Delivery Status  Late_delivery_risk  \
# 0     DEBIT          91.250000  Advance shipping                   0
# 1  TRANSFER        -249.089996     Late delivery                   1
# 2      CASH        -247.779999  Shipping on time                   0
# 3     DEBIT          22.860001  Advance shipping                   0
# 4   PAYMENT         134.210007  Advance shipping                   0
#
#     Category Name Customer Country  Customer Id Customer Segment  \
# 0  Sporting Goods      Puerto Rico        20755         Consumer
# 1  Sporting Goods      Puerto Rico        19492         Consumer
# 2  Sporting Goods          EE. UU.        19491         Consumer
# 3  Sporting Goods          EE. UU.        19490      Home Office
# 4  Sporting Goods      Puerto Rico        19489        Corporate
#
#   Department Name        Market  ... Order Item Discount Rate  \
# 0         Fitness  Pacific Asia  ...                     0.04
# 1         Fitness  Pacific Asia  ...                     0.05
# 2         Fitness  Pacific Asia  ...                     0.06
# 3         Fitness  Pacific Asia  ...                     0.07
# 4         Fitness  Pacific Asia  ...                     0.09
#
#   Order Item Product Price   Sales    Order Region     Order Status  \
# 0                   327.75  327.75  Southeast Asia         COMPLETE
# 1                   327.75  327.75      South Asia          PENDING
# 2                   327.75  327.75      South Asia           CLOSED
# 3                   327.75  327.75         Oceania         COMPLETE
# 4                   327.75  327.75         Oceania  PENDING_PAYMENT
#
#    Product Name shipping date (DateOrders)   Shipping Mode BenefitBracket  \
# 0  Smart watch         2018-02-03 22:56:00  Standard Class         Profit
# 1  Smart watch         2018-01-18 12:27:00  Standard Class           Loss
# 2  Smart watch         2018-01-17 12:06:00  Standard Class           Loss
# 3  Smart watch         2018-01-16 11:45:00  Standard Class         Profit
# 4  Smart watch         2018-01-15 11:24:00  Standard Class         Profit
#
#   Order Item Discount Bracket
# 0                        <10%
# 1                        <10%
# 2                        <10%
# 3                        <10%
# 4                        <10%
#
# [5 rows x 22 columns]

# %%
# Product Price
ds['Order Item Product Price'].value_counts()
# Out:
# 59.990002      24820
# 129.990005     22372
# 50.000000      21035
# 49.980000      19298
# 399.980011     17325
#                ...
# 349.989990        40
# 329.989990        27
# 599.989990        21
# 1999.989990       15
# 999.989990        10
# Name: Order Item Product Price, Length: 75, dtype: int64

# %%
# Range for the Product Price
ProdPrice_brackets = [0, 500, 1000, 1500, 2000]
ProdPrice_labels = ['<500', '500-1000', '1000-1500', '1500-2000']

# Assign salary brackets to dataset
ds['Product Price Bracket'] = pd.cut(ds['Order Item Product Price'], bins=ProdPrice_brackets, labels=ProdPrice_labels)

# View the updated dataset
ds.head()
# Out:
#        Type  Benefit per order   Delivery Status  Late_delivery_risk  \
# 0     DEBIT          91.250000  Advance shipping                   0
# 1  TRANSFER        -249.089996     Late delivery                   1
# 2      CASH        -247.779999  Shipping on time                   0
# 3     DEBIT          22.860001  Advance shipping                   0
# 4   PAYMENT         134.210007  Advance shipping                   0
#
#     Category Name Customer Country  Customer Id Customer Segment  \
# 0  Sporting Goods      Puerto Rico        20755         Consumer
# 1  Sporting Goods      Puerto Rico        19492         Consumer
# 2  Sporting Goods          EE. UU.        19491         Consumer
# 3  Sporting Goods          EE. UU.        19490      Home Office
# 4  Sporting Goods      Puerto Rico        19489        Corporate
#
#   Department Name        Market  ... Order Item Product Price   Sales  \
# 0         Fitness  Pacific Asia  ...                   327.75  327.75
# 1         Fitness  Pacific Asia  ...                   327.75  327.75
# 2         Fitness  Pacific Asia  ...                   327.75  327.75
# 3         Fitness  Pacific Asia  ...                   327.75  327.75
# 4         Fitness  Pacific Asia  ...                   327.75  327.75
#
#      Order Region     Order Status  Product Name shipping date (DateOrders)  \
# 0  Southeast Asia         COMPLETE  Smart watch         2018-02-03 22:56:00
# 1      South Asia          PENDING  Smart watch         2018-01-18 12:27:00
# 2      South Asia           CLOSED  Smart watch         2018-01-17 12:06:00
# 3         Oceania         COMPLETE  Smart watch         2018-01-16 11:45:00
# 4         Oceania  PENDING_PAYMENT  Smart watch         2018-01-15 11:24:00
#
#     Shipping Mode BenefitBracket Order Item Discount Bracket  \
# 0  Standard Class         Profit                        <10%
# 1  Standard Class           Loss                        <10%
# 2  Standard Class           Loss                        <10%
# 3  Standard Class         Profit                        <10%
# 4  Standard Class         Profit                        <10%
#
#   Product Price Bracket
# 0                  <500
# 1                  <500
# 2                  <500
# 3                  <500
# 4                  <500
#
# [5 rows x 23 columns]

# %%
# Sales
ds['Sales'].value_counts()
# Out:
# 129.990005    22372
# 399.980011    17325
# 199.990005    15622
# 299.980011    13729
# 179.970001     5016
#               ...
# 999.989990       10
# 379.959992       10
# 198.000000        9
# 396.000000        9
# 99.000000         9
# Name: Sales, Length: 193, dtype: int64

# %%
# # Range for the Sales
Sales_brackets = [0, 500, 1000, 1500, 2000]
Sales_labels = ['<500', '500-1000', '1000-1500', '1500-2000']

# Assign salary brackets to dataset
ds['Sales Bracket'] = pd.cut(ds['Sales'], bins=Sales_brackets, labels=Sales_labels)

# View the updated dataset
ds.head()
# Out:
#        Type  Benefit per order   Delivery Status  Late_delivery_risk  \
# 0     DEBIT          91.250000  Advance shipping                   0
# 1  TRANSFER        -249.089996     Late delivery                   1
# 2      CASH        -247.779999  Shipping on time                   0
# 3     DEBIT          22.860001  Advance shipping                   0
# 4   PAYMENT         134.210007  Advance shipping                   0
#
#     Category Name Customer Country  Customer Id Customer Segment  \
# 0  Sporting Goods      Puerto Rico        20755         Consumer
# 1  Sporting Goods      Puerto Rico        19492         Consumer
# 2  Sporting Goods          EE. UU.        19491         Consumer
# 3  Sporting Goods          EE. UU.        19490      Home Office
# 4  Sporting Goods      Puerto Rico        19489        Corporate
#
#   Department Name        Market  ...   Sales    Order Region     Order Status  \
# 0         Fitness  Pacific Asia  ...  327.75  Southeast Asia         COMPLETE
# 1         Fitness  Pacific Asia  ...  327.75      South Asia          PENDING
# 2         Fitness  Pacific Asia  ...  327.75      South Asia           CLOSED
# 3         Fitness  Pacific Asia  ...  327.75         Oceania         COMPLETE
# 4         Fitness  Pacific Asia  ...  327.75         Oceania  PENDING_PAYMENT
#
#    Product Name  shipping date (DateOrders)   Shipping Mode BenefitBracket  \
# 0  Smart watch          2018-02-03 22:56:00  Standard Class         Profit
# 1  Smart watch          2018-01-18 12:27:00  Standard Class           Loss
# 2  Smart watch          2018-01-17 12:06:00  Standard Class           Loss
# 3  Smart watch          2018-01-16 11:45:00  Standard Class         Profit
# 4  Smart watch          2018-01-15 11:24:00  Standard Class         Profit
#
#   Order Item Discount Bracket Product Price Bracket Sales Bracket
# 0                        <10%                  <500          <500
# 1                        <10%                  <500          <500
# 2                        <10%                  <500          <500
# 3                        <10%                  <500          <500
# 4                        <10%                  <500          <500
#
# [5 rows x 24 columns]

# %%
# Region of the order
ds['Order Region'].value_counts()
# Out:
# Central America    28341
# Western Europe     27109
# South America      14935
# Oceania            10148
# Northern Europe     9792
# Southeast Asia      9539
# Southern Europe     9431
# Caribbean           8318
# West of USA         7993
# South Asia          7731
# Eastern Asia        7280
# East of USA         6915
# West Asia           6009
# US Center           5887
# South of  USA       4045
# Eastern Europe      3920
# West Africa         3696
# North Africa        3232
# East Africa         1852
# Central Africa      1677
# Southern Africa     1157
# Canada               959
# Central Asia         553
# Name: Order Region, dtype: int64

# %%
# Order Status
ds['Order Status'].value_counts()
# Out:
# COMPLETE           59491
# PENDING_PAYMENT    39832
# PROCESSING         21902
# PENDING            20227
# CLOSED             19616
# ON_HOLD             9804
# SUSPECTED_FRAUD     4062
# CANCELED            3692
# PAYMENT_REVIEW      1893
# Name: Order Status, dtype: int64

# %%
# Name of the Product
ds['Product Name'].value_counts()
# Out:
# Perfect Fitness Perfect Rip Deck                 24515
# Nike Men's CJ Elite 2 TD Football Cleat          22246
# Nike Men's Dri-FIT Victory Golf Polo             21035
# O'Brien Men's Neoprene Life Vest                 19298
# Field & Stream Sportsman 16 Gun Fire Safe        17325
#                                                  ...
# Stiga Master Series ST3100 Competition Indoor       27
# SOLE E35 Elliptical                                 15
# Bushnell Pro X7 Jolt Slope Rangefinder              11
# Bowflex SelectTech 1090 Dumbbells                   10
# SOLE E25 Elliptical                                 10
# Name: Product Name, Length: 118, dtype: int64

# %%
# Date of shipping
ds['shipping date (DateOrders)'].value_counts()
# Out:
# 2016-01-05 05:58:00    10
# 2015-07-16 10:14:00    10
# 2015-04-17 22:16:00    10
# 2015-05-27 06:48:00    10
# 2015-05-09 18:02:00    10
#                        ..
# 2015-03-29 18:06:00     1
# 2015-04-02 12:40:00     1
# 2015-04-02 23:10:00     1
# 2015-03-31 07:03:00     1
# 2016-01-21 05:56:00     1
# Name: shipping date (DateOrders), Length: 63701, dtype: int64

# %%
# Mode of shipping
ds['Shipping Mode'].value_counts()
# Out:
# Standard Class    107752
# Second Class       35216
# First Class        27814
# Same Day            9737
# Name: Shipping Mode, dtype: int64

# %% [markdown]
# ## Exporting the Cleaned Dataset as a New CSV

# %%
# Writing the Cleaned Data to CSV
ds.to_csv('Cleaned_DataCoSupplyChainDataset.csv',index=False)

# %%
# Displaying First Five values of the Cleaned Dataset
ds.head()
# Out:
#        Type  Benefit per order   Delivery Status  Late_delivery_risk  \
# 0     DEBIT          91.250000  Advance shipping                   0
# 1  TRANSFER        -249.089996     Late delivery                   1
# 2      CASH        -247.779999  Shipping on time                   0
# 3     DEBIT          22.860001  Advance shipping                   0
# 4   PAYMENT         134.210007  Advance shipping                   0
#
#     Category Name Customer Country  Customer Id Customer Segment  \
# 0  Sporting Goods      Puerto Rico        20755         Consumer
# 1  Sporting Goods      Puerto Rico        19492         Consumer
# 2  Sporting Goods          EE. UU.        19491         Consumer
# 3  Sporting Goods          EE. UU.        19490      Home Office
# 4  Sporting Goods      Puerto Rico        19489        Corporate
#
#   Department Name        Market  ...   Sales    Order Region     Order Status  \
# 0         Fitness  Pacific Asia  ...  327.75  Southeast Asia         COMPLETE
# 1         Fitness  Pacific Asia  ...  327.75      South Asia          PENDING
# 2         Fitness  Pacific Asia  ...  327.75      South Asia           CLOSED
# 3         Fitness  Pacific Asia  ...  327.75         Oceania         COMPLETE
# 4         Fitness  Pacific Asia  ...  327.75         Oceania  PENDING_PAYMENT
#
#    Product Name  shipping date (DateOrders)   Shipping Mode BenefitBracket  \
# 0  Smart watch          2018-02-03 22:56:00  Standard Class         Profit
# 1  Smart watch          2018-01-18 12:27:00  Standard Class           Loss
# 2  Smart watch          2018-01-17 12:06:00  Standard Class           Loss
# 3  Smart watch          2018-01-16 11:45:00  Standard Class         Profit
# 4  Smart watch          2018-01-15 11:24:00  Standard Class         Profit
#
#   Order Item Discount Bracket Product Price Bracket Sales Bracket
# 0                        <10%                  <500          <500
# 1                        <10%                  <500          <500
# 2                        <10%                  <500          <500
# 3                        <10%                  <500          <500
# 4                        <10%                  <500          <500
#
# [5 rows x 24 columns]

# %%
# Displaying Columns of the Cleaned Dataset
ds.columns
# Out:
# Index(['Type', 'Benefit per order', 'Delivery Status', 'Late_delivery_risk',
#        'Category Name', 'Customer Country', 'Customer Id', 'Customer Segment',
#        'Department Name', 'Market', 'Order Country', 'order date (DateOrders)',
#        'Order Item Discount Rate', 'Order Item Product Price', 'Sales',
#        'Order Region', 'Order Status', 'Product Name',
#        'shipping date (DateOrders)', 'Shipping Mode', 'BenefitBracket',
#        'Order Item Discount Bracket', 'Product Price Bracket',
#        'Sales Bracket'],
#       dtype='object')

# %%
# Shape of the Cleaned Dataset
ds.shape
# Out:
# (180519, 24)

# %%
# Checking for Duplicates in the Cleaned Dataset
ds.duplicated().sum()
# Out:
# 0
